# %%
import os

# Function to read and return the content of a file
def get_file_content(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        content = file.read()
    return content

# Function to delete a file
def delete_file(file_path):
    os.remove(file_path)
    print(f"Deleted file: {file_path}")

# Function to find and delete duplicates based on content
def find_and_delete_duplicates(directory):
    duplicate_key = "-Rami’s MacBook Pro"
    # Get the list of files in the specified directory
    files = os.listdir(directory)
    
    # Iterate through each file in the directory
    for file in files:
        file.replace(".md", "")
        # Check if the file name ends with "-Rami’s MacBook Pro (3)"
        if not file.endswith(duplicate_key):
            continue

        # Construct the base file name without the suffix
        base_filename = file.replace(duplicate_key, "")
        base_file_path = os.path.join(directory, base_filename)

        print(f"Checking {base_filename} and {file}")
        # Check if the base file exists
        if os.path.isfile(base_file_path):
            # Get the content of the base file and the current file
            base_content = get_file_content(base_file_path)
            current_content = get_file_content(os.path.join(directory, file))
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(directory, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(directory, file))


# Specify the path to the directory containing the files
directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/1 Zettelkasten/"
test_directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/0 Journal/0 Daily copy/"
# Call the function to find and delete duplicates
find_and_delete_duplicates(test_directory_path)

# %%
import os
import re

# Function to read and return the content of a file
def get_file_content(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        content = file.read()
    return content

# Function to delete a file
def delete_file(file_path):
    os.remove(file_path)
    print(f"Deleted file: {file_path}")

# Function to find and delete duplicates based on content
def find_and_delete_duplicates(directory):
    date_pattern = r"\d{4}-\d{2}-\d{2}-\d{2}-\d{2}-\d{2}"  # Pattern for matching "YYYY-MM-DD-HH-MM-SS"
    # Get the list of files in the specified directory
    files = os.listdir(directory)
    
    # Iterate through each file in the directory
    for file in files:
        # Check if the file name ends with "-Rami’s MacBook Pro (3)"
        if not re.match(r".*\s\(conflict\s{}\).*".format(date_pattern), file):
            continue

        # Construct the base file name without the suffix
        base_filename = file.replace(re.match(r".*(\s\(conflict\s{}\)).*".format(date_pattern), file).groups()[0], "")
        base_file_path = os.path.join(directory, base_filename)

        print(f"Checking {base_filename} and {file}")
        # Check if the base file exists
        if os.path.isfile(base_file_path):
            # Get the content of the base file and the current file
            base_content = get_file_content(base_file_path)
            current_content = get_file_content(os.path.join(directory, file))
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(directory, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(directory, file))


# Specify the path to the directory containing the files
directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/1 Zettelkasten/"
test_directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/0 Journal/0 Daily copy/"
# Call the function to find and delete duplicates
find_and_delete_duplicates(test_directory_path)

# %%
import os
import re

# Function to read and return the content of a file
def get_file_content(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        content = file.read()
    return content

# Function to delete a file
def delete_file(file_path):
    os.remove(file_path)
    print(f"Deleted file: {file_path}")

# Function to find and delete duplicates based on content
def find_and_delete_duplicates(directory):
    count = 0
    # constants
    # Check if the file name ends with specific suffixes
    suffixes = ["-Rami’s MacBook Pro (3)", "-Rami’s MacBook Pro", "-Rami’s MacBook Pro (2)", "-Rami’s MacBook Pro (4)"]
    date_pattern = r"\d{4}-\d{2}-\d{2}-\d{2}-\d{2}-\d{2}"  # Pattern for matching "YYYY-MM-DD-HH-MM-SS"
    # Get the list of files in the specified directory
    
    for root, dirs, files in os.walk(directory):
      # Iterate through each file in the directory      
      for file in files:
        # Check if the file name ends with specific suffixes
        if not any(file.endswith(suffix) for suffix in suffixes) and not re.match(r".*\s\(conflict\s{}\).*".format(date_pattern), file):
            continue

        # Construct the base file name without the suffix
        base_filename = file.replace(re.match(r".*(\s\(conflict\s{}\)).*".format(date_pattern), file).groups()[0], "")
        base_file_path = os.path.join(root, base_filename)

        print(f"Checking {base_filename} and {file}")
        # Check if the base file exists or if the file contains "Lebanese gorl" in its name
        if os.path.isfile(base_file_path):
            try:
                # Get the content of the base file and the current file
                base_content = get_file_content(base_file_path)
                current_content = get_file_content(os.path.join(root, file))
            except:
                print(f"Error reading {base_filename} or {file}")
                continue
            count += 1
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(root, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(root, file))

# Specify the path to the directory containing the files
directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/"
test_directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/obsidian copy/"
# Call the function to find and delete duplicates
find_and_delete_duplicates(directory_path)

# %%
import os

# Function to read and return the content of a file
def get_file_content(file_path):
    with open(file_path, 'r', encoding='utf-8', errors='ignore') as file:
        content = file.read()
    return content

# Function to delete a file
def delete_file(file_path):
    os.remove(file_path)
    print(f"Deleted file: {file_path}")

# Function to find and delete duplicates based on content
def find_and_delete_duplicates(directory):
    count = 0
    duplicate_key = "-Rami’s MacBook Pro"
    # Get the list of files in the specified directory
    
    for root, dirs, files in os.walk(directory):
      # Iterate through each file in the directory      
      for file in files:
        # Check if the file name ends with "-Rami’s MacBook Pro (3)"
        if not file.endswith(duplicate_key + ".md"):
            continue

        # Construct the base file name without the suffix
        base_filename = file.replace(duplicate_key, "")
        base_file_path = os.path.join(root, base_filename)

        print(f"Checking {base_filename} and {file}")
        # Check if the base file exists or if the file contains "Lebanese gorl" in its name
        if os.path.isfile(base_file_path):
            print(count)
            try:
                # Get the content of the base file and the current file
                base_content = get_file_content(base_file_path)
                current_content = get_file_content(os.path.join(root, file))
            except:
                print(f"Error reading {base_filename} or {file}")
                continue
            count += 1
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(root, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(root, file))
                base_content = get_file_content(base_file_path)
                current_content = get_file_content(os.path.join(root, file))
            except:
                print(f"Error reading {base_filename} or {file}")
                continue
            count += 1
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(root, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(root, file))
                base_content = get_file_content(base_file_path)
                current_content = get_file_content(os.path.join(root, file))
            except:
                print(f"Error reading {base_filename} or {file}")
                continue
            count += 1
            print(f"Comparing {base_filename} with {file}")
            # Compare the content lengths and delete the file with less content
            if len(current_content) < len(base_content):
                delete_file(os.path.join(root, file))
                print(f"Deleted file: {file}")
            else:
                # place the content of the current file in the base file
                with open(base_file_path, 'w', encoding='utf-8', errors='ignore') as base_file:
                    base_file.write(current_content)
                # Delete the current file
                delete_file(os.path.join(root, file))
    print(f"Total duplicates found: {count}")


# Specify the path to the directory containing the files
directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/Obsidian/"
test_directory_path = "/Users/rami-ibm/Library/CloudStorage/OneDrive-Personal/obsidian copy/"
# Call the function to find and delete duplicates
find_and_delete_duplicates(directory_path)
